# %%
import os 
from PIL import Image
import matplotlib.pyplot as plt

files = os.listdir('/media/riccardoricci/Melgani/Riccardo/Datasets/segmentation/Semantic segmentation/second_dataset/public/test/im1')

print(files)
file = files[1]

im1 = Image.open("/media/riccardoricci/Melgani/Riccardo/Datasets/segmentation/Semantic segmentation/second_dataset/public/test/im1/"+file)
im2 = Image.open("/media/riccardoricci/Melgani/Riccardo/Datasets/segmentation/Semantic segmentation/second_dataset/public/test/im2/"+file)

# Display in a figure
fig = plt.figure(figsize=(10, 10))
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(im1)
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(im2)
# Out:
# ['00017.png', '00018.png', '00021.png', '00031.png', '00045.png', '00050.png', '00052.png', '00056.png', '00057.png', '00065.png', '00067.png', '00068.png', '00088.png', '00094.png', '00098.png', '00113.png', '00129.png', '00139.png', '00151.png', '00155.png', '00162.png', '00172.png', '00185.png', '00190.png', '00191.png', '00193.png', '00200.png', '00206.png', '00210.png', '00222.png', '00226.png', '00231.png', '00242.png', '00253.png', '00257.png', '00259.png', '00260.png', '00269.png', '00271.png', '00279.png', '00287.png', '00305.png', '00310.png', '00322.png', '00333.png', '00341.png', '00343.png', '00346.png', '00356.png', '00360.png', '00361.png', '00372.png', '00374.png', '00376.png', '00413.png', '00415.png', '00417.png', '00423.png', '00425.png', '00436.png', '00441.png', '00451.png', '00453.png', '00462.png', '00468.png', '00469.png', '00483.png', '00498.png', '00505.png', '00507.png', '00510.png', '00522.png', '00541.png', '00547.png', '00575.png', '00602.png', '00609.pn
# ...

# %%
# Open the questions and answers
import json


with open('/media/riccardoricci/Data/Riccardo/Change_Detection/CDVQA_dataset/Test_CD_VQA_summary_Final.json') as f:
    questions_answers = json.load(f)

for info in questions_answers["CDVQA"]:
    # print(len(info["questions"]))
    if(info["image"]==file):
        for question in info["questions"]:
            print(question)
        for answer in info["answer"]:
            print(answer)
# Out:
# Have the regions of non-vegetated ground surface changed?
# Did the areas of trees change?
# Did the areas of low vegetation change?
# Did the areas of water change?
# Have the regions of buildings changed?
# Have the regions of playgrounds changed?
# Have the areas of trees changed in the first image?
# Did the regions of low vegetation change in the pre-event image?
# Have the regions of buildings changed in the first image?
# Did the areas of non-vegetated ground surface change in the post-change image?
# Did the regions of trees change in the post-event image?
# Have the areas of low vegetation changed in the second image?
# Have the regions of buildings changed in the second image?
# Did the regions of playgrounds change in the post-event image?
# Did the regions of non-vegetated ground surface increase?
# Have the areas of trees increased?
# Have the areas of low vegetation increased?
# Have the regions of water increased?
# Have the areas of buildings increased?
# ...
